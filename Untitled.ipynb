# %%
from pydicom import dcmread
ds = dcmread("/mnt/hdd8/axle/dev/dcmtk_reader/data/pydicom-data/data/emri_small_jpeg_ls_lossless.dcm")
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 242
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Enhanced MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.2.1143.6455556726214900995651753669640998622
# (0002, 0010) Transfer Syntax UID                 UI: JPEG-LS Lossless Image Compression
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.2.1143.107.104.103.115.2.2.4
# (0002, 0013) Implementation Version Name         SH: 'GDCM 2.2.4'
# (0002, 0016) Source Application Entity Title     AE: 'gdcmconv'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'T1', 'NONE']
# (0008, 0012) Instance Creation Date              DA: '20000101'
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
data = ds.pixel_array
plt.imshow(ds.pixel_array[:,:].squeeze())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 data = ds.pixel_array
#       4 plt.imshow(ds.pixel_array[:,:].squeeze())
#       5 plt.show()
#
# File ~/.local/lib/python3.9/site-packages/pydicom/dataset.py:1887, in Dataset.pixel_array(self)
#    1872 @property
#    1873 def pixel_array(self) -> "numpy.ndarray":
#    1874     """Return the pixel data as a :class:`numpy.ndarray`.
#    1875
#    1876     .. versionchanged:: 1.4
#    (...)
#    1885         :class:`numpy.ndarray`.
#    1886     """
# -> 1887     self.convert_pixel_data()
#    1888     return cast("numpy.ndarray", self._pixel_array)
#
# File ~/.local/lib/python3.9/site-packages/pydicom/dataset.py:1444, in Dataset.convert_pixel_data(self, handler_name)
# ...
